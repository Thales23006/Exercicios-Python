# %% [markdown]
# <a href="https://colab.research.google.com/github/Thales23006/Exercicios-Python/blob/main/Atividade_Controle_de_Sem%C3%A1foro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Qual é a cor do semáforo? Digite 1-verde Digite 2-amarelo Digite 3-vermelho ", end='', flush=True)
cor = int(input())
if cor == 1:
    print("Prossiga!")
    print(" Com quantos km o carro está?")
    velocidade = int(input())
    if velocidade > 66:
        print(" Excesso de velocidade")
        if velocidade > 80:
            print(" Multa gravíssima! Valor:600,00")
        else:
            print(" Multa grave  - Valor: R$ 220,00 ")
    else:
        print("Ok")
else:
    if cor == 2:
        print(" Atenção ")
        print(" Com quantos km o carro está?")
        velocidade = int(input())
        if velocidade > 66:
            print(" Excesso de velocidade")
            if velocidade > 80:
                print(" Multa gravíssima! Valor: R$600,00")
            else:
                print(" Multa grave  - Valor: R$ 220,00 ")
        else:
            print("Ok")
    else:
        if cor == 3:
            print("Pare ")
            print("Parou? SIM - Digite 1 NÃO - Digite 2 ", end='', flush=True)
            pare = int(input())
            if pare == 1:
                print("ok")
            else:
                print("Multa por ultrapassar o sinal vermelho! - Valor:R$293,47")
                print(" Com quantos km o carro está?")
                velocidade = int(input())
                if velocidade > 66:
                    print(" Excesso de velocidade")
                    if velocidade > 80:
                        print(" Multa gravíssima! Valor:R$600,00")
                    else:
                        print(" Multa grave  - Valor: R$ 220,00")
                else:
                    print("Ok")
        else:
            print("Inválido")
# Out:
# Qual é a cor do semáforo? Digite 1-verde Digite 2-amarelo Digite 3-vermelho 2
#  Atenção
#  Com quantos km o carro está?
# 100
#  Excesso de velocidade
#  Multa gravíssima! Valor: R$600,00
